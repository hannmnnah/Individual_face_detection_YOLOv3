# %% [markdown]
# # MOUNT

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#다크넷 경로
# %cd /content/gdrive/MyDrive/Colab_Notebooks/proj/data/yolo
# !chmod +x ./darknet
# %ls
# Out:
# /content/gdrive/MyDrive/Colab_Notebooks/proj/data/yolo
# bad.list   chart_yolov3.png  data_predict/  result/             train_valid/
# chart.png  darknet*          ipynb/         train_resize_Hana/  yoloface/

# %%
#colab

#1. predict할 파일 들어있는 폴더 (txt파일에 입력될 path기 때문에 절대경로 추천, 마지막에 꼭 '/' 넣어줘야함.)
image_directory = '/content/gdrive/MyDrive/Colab_Notebooks/proj/data/yolo/data_predict/captured_img3/'
#2. 확장자
extension = "*.jpg"
#3. txt파일 저장경로 및 파일 이름
save_at = './re.txt'


import glob
import PIL
import PIL.Image as Image
import make_path_txt


d=0
with open(make_path_txt.make_data_path(image_directory,extension, save_at),'r') as fobj:
        image_List = [[num for num in line.split()] for line in fobj]
        for images in image_List:
            # print(images[0])
            img=images[0]
            #predict command, 마지막에 변수 들어가는 거 지우지 말고 사용하시는 command만 복붙 바람.
            # !./darknet detector test train_resize_Hana/r1mini.data train_resize_Hana/yolov3-tiny.cfg train_resize_Hana/backup_tiny3/yolov3-tiny_final.weights $img
            #다크넷 경로 + prdictions.jpg
            predicted_image = Image.open('/content/gdrive/My Drive/Colab_Notebooks/proj/data/yolo/predictions.jpg')
            #predict 결과 저장할 경로+ 파일이름
            output = '/content/gdrive/MyDrive/Colab_Notebooks/proj/data/yolo/predicted_img{}.jpg'.format(d)
            predicted_image.save(output) 
            d+=1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Cannot load image data/labels/119_4.png
# Cannot load image data/labels/120_4.png
# Cannot load image data/labels/121_4.png
# Cannot load image data/labels/122_4.png
# Cannot load image data/labels/123_4.png
# Cannot load image data/labels/124_4.png
# Cannot load image data/labels/125_4.png
# Cannot load image data/labels/126_4.png
# Cannot load image data/labels/32_5.png
# Cannot load image data/labels/33_5.png
# Cannot load image data/labels/34_5.png
# Cannot load image data/labels/35_5.png
# Cannot load image data/labels/36_5.png
# Cannot load image data/labels/37_5.png
# Cannot load image data/labels/38_5.png
# Cannot load image data/labels/39_5.png
# Cannot load image data/labels/40_5.png
# Cannot load image data/labels/41_5.png
# Cannot load image data/labels/42_5.png
# Cannot load image data/labels/43_5.png
# Cannot load image data/labels/44_5.png
# Cannot load image data/labels/45_5.png
# Cannot load image data/labels/46_5.png
# ...
