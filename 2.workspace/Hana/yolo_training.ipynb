# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
ls /content/gdrive/MyDrive/Colab_Notebooks/darknet/cudnn/cuda/
# Out:
# ls: cannot access '/content/gdrive/MyDrive/Colab_Notebooks/darknet/cudnn/cuda/': No such file or directory

# %%
ls /usr/local/cuda
# Out:
# /usr/local/cuda@

# %%
# !ls /usr/local/cuda
# Out:
# bin	   cuda-10.1  _gcs_config_ops.so  LICENSE.txt  sbin	  src
# cuda	   etc	      include		  licensing    setup.cfg  xgboost
# cuda-10.0  games      lib		  man	       share

# %%
# !ls /usr/local/cuda/include

# %%
#cuDNN 파일 경로 / cuDNN 버전 확인

# !cat /usr/local/cuda/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# cat: /usr/local/cuda/cuda/include/cudnn_version.h: No such file or directory

# %%
# 다크넷 폴더 경로
# %cd /content/gdrive/MyDrive/Colab_Notebooks/darknet/bin/darknet
# Out:
# /content/gdrive/MyDrive/Colab_Notebooks/darknet/bin/darknet

# %%
# !ls
# Out:
# bad.list	       darknet			 predictions.jpg  train
# chart.png	       fastandfurious_short.mov  result_past	  train_2
# chart_yolov3-tiny.png  frame29.jpg		 test.mov

# %%
# !chmod +x ./darknet

# %%
# %ls
# Out:
# bad.list               darknet*                  predictions.jpg  train/
# chart.png              fastandfurious_short.mov  result_past/     train_2/
# chart_yolov3-tiny.png  frame29.jpg               test.mov

# %%
# !LD_LiBRARY_PATH=/usr/local/cuda/cuda/lib64 ./darknet detector train train_2/r1mini.data train_2/yolov3-tiny.cfg -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  Tensor Cores are used.
#
#  5566: 0.031565, 0.031391 avg loss, 0.000010 rate, 0.451737 seconds, 356224 images, 0.226510 hours left
# Loaded: 1.136580 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.904406), count: 13, class_loss = 0.028654, iou_loss = 0.013839, total_loss = 0.042493
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.881769), count: 18, class_loss = 0.014534, iou_loss = 0.017234, total_loss = 0.031768
#  total_bbox = 354996, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.917195), count: 19, class_loss = 0.005894, iou_loss = 0.011407, total_loss = 0.017300
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.874650), count: 13, class_loss = 0.000984, iou_loss = 0.013284, total_loss = 0.014268
# ...

# %%
ls /usr/local/cuda/lib64
# Out:
# /usr/local/cuda/lib64@

# %%
ls
# Out:
# darknet*  r1mini/  r1mini.data  r1mini.names  train.txt  yolov3-tiny.cfg
