# %%
# !ls ./data

data_path = './data/'
# Out:
# Fast.and.Furious.7.2015.1080p.HDTV.KorSub.x264.mp4
# captured_img
# captured_img2
# captured_img3
# movie_cap
# movie_jpg
# test.mp4

# %%
#영화 total frame 수
import cv2

videoFile = data_path+'Fast.and.Furious.7.2015.1080p.HDTV.KorSub.x264.mp4'
cap = cv2.VideoCapture(videoFile)
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(' length : %d' % length,'\n','width : %d' % width,'\n','height : %d' % height, '\n', 'fps : %d' % fps)
# Out:
#  length : 246745
#  width : 1920
#  height : 1080
#  fps : 29

# %%
#test video total frame 수
import cv2

videoFile = data_path+'test.mp4'
cap = cv2.VideoCapture(videoFile)
length = float(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = float(cap.get(cv2.CAP_PROP_FPS))
run = cap.get(cv2.CAP_PROP_POS_MSEC)
print(' length : %d' % length,'\n','width : %d' % width,'\n','height : %d' % height, '\n', 'fps : %d' % fps,'\n','run : {}'.format(length/fps))
# Out:
#  length : 677
#  width : 1290
#  height : 712
#  fps : 29
#  run : 22.633333333333333

# %%
# %%writefile ./videocap.py
import cv2
import os
import time

def video_cap(videoFile, imgpath,intro_skips=0.0,time_skips=1.0):
    start = time.time()
    cap = cv2.VideoCapture(videoFile)
    count = 0
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret :
            cv2.imwrite(imgpath+"/frame%d.jpg" % count, frame)
            print('%d.jpg done' % count)
            cap.set(cv2.CAP_PROP_POS_MSEC,intro_skips + count*time_skips)
            count += 1
        
        else:
            break
        
    cap.release()

    runtime = 'runtime : {}'.format(time.time()-start)
    return runtime

#.py 만든 커널
# Out:
# Overwriting ./videocap.py

# %%
import videocap as vc

videoFile = data_path+'test.mp4'
imgpath = data_path+'captured_img2/'
time_skips = float(1000) #단위가 밀리초, 그래서 이건 1초를 의미함

vc.video_cap(videoFile, imgpath, time_skips)
#캡쳐 속도가 영상 속도는 아니라는 걸 알 수 있음
# Out:
# 0.jpg done
# 1.jpg done
# 2.jpg done
# 3.jpg done
# 4.jpg done
# 5.jpg done
# 6.jpg done
# 7.jpg done
# 8.jpg done
# 9.jpg done
# 10.jpg done
# 11.jpg done
# 12.jpg done
# 13.jpg done
# 14.jpg done
# 15.jpg done
# 16.jpg done
# 17.jpg done
# 18.jpg done
# 19.jpg done
# 20.jpg done
# 21.jpg done
# 22.jpg done
# 23.jpg done
# 'runtime : 2.2277019023895264'

# %%
#함수 만들었던 커널

import cv2
import os
import time

videoFile = data_path+'test.mp4'
imgpath = data_path+'captured_img3/'
time_skips = float(1000) #단위가 밀리초, 그래서 이건 1초를 의미함
# intro_skips = float(50000) #50초
# end_time = float(7740000)
intro_skips = float(10000) #10초
# end_time = float(15000)


def video_cap(videoFile, imgpath,intro_skips=0.0,time_skips=1.0):
    start = time.time()
    cap = cv2.VideoCapture(videoFile)
    count = 0
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret :
            cv2.imwrite(imgpath+"/frame%d.jpg" % count, frame)
            print('%d.jpg done' % count)
            cap.set(cv2.CAP_PROP_POS_MSEC,intro_skips + count*time_skips)
            count += 1
        
        else:
            break
        
    cap.release()

    runtime = 'runtime : {}'.format(time.time()-start)
    return runtime

video_cap(videoFile, imgpath,intro_skips,time_skips)
# Out:
# 0.jpg done
# 1.jpg done
# 2.jpg done
# 3.jpg done
# 4.jpg done
# 5.jpg done
# 6.jpg done
# 7.jpg done
# 8.jpg done
# 9.jpg done
# 10.jpg done
# 11.jpg done
# 12.jpg done
# 13.jpg done
# 'runtime : 1.7501568794250488'

# %% [markdown]
# -----------------------

# %% [markdown]
# # 이제 영화 ㄱ

# %%
import videocap as vc

data_path = './data/'
videoFile = data_path+'Fast.and.Furious.7.2015.1080p.HDTV.KorSub.x264.mp4'
imgpath = data_path+'movie_cap/'
time_skips = float(4000) #단위가 밀리초, 그래서 이건 4초를 의미함, 이렇게하면 2천여장정도 나올 것
intro_skips = float(50000) #skip_intro 이 영화의 경우 50초부터 영화 시작

vc.video_cap(videoFile, imgpath, time_skips=time_skips, intro_skips=intro_skips)
# Out:
# 0.jpg done
# 1.jpg done
# 2.jpg done
# 3.jpg done
# 4.jpg done
# 5.jpg done
# 6.jpg done
# 7.jpg done
# 8.jpg done
# 9.jpg done
# 10.jpg done
# 11.jpg done
# 12.jpg done
# 13.jpg done
# 14.jpg done
# 15.jpg done
# 16.jpg done
# 17.jpg done
# 18.jpg done
# 19.jpg done
# 20.jpg done
# 21.jpg done
# 22.jpg done
# 23.jpg done
# 24.jpg done
# 25.jpg done
# 26.jpg done
# 27.jpg done
# 28.jpg done
# 29.jpg done
# 30.jpg done
# 31.jpg done
# 32.jpg done
# 33.jpg done
# 34.jpg done
# 35.jpg done
# 36.jpg done
# 37.jpg done
# 38.jpg done
# 39.jpg done
# 40.jpg done
# 41.jpg done
# 42.jpg done
# 43.jpg done
# 44.jpg done
# 45.jpg done
# 46.jpg done
# 47.jpg done
# 48.jpg done
# 49.jpg done
# 50.jpg done
# 51.jpg done
# 52.jpg done
# 53.jpg done
# 54.jpg done
# 55.jpg done
# 56.jpg done
# 57.jpg done
# 58.jpg done
# 59.jpg done
# 60.jpg done
# 61.jpg done
# 62.jpg done
# 63.jpg done
# 64.jpg done
# 65.jpg done
# 66.jpg done
# 67.jpg done
# 68.jpg done
# 69.jpg done
# 70.jpg done
# 71.jpg done
# ...
