# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !tar xzvf /content/gdrive/MyDrive/darknet/cudnn/cudnn-10.1-linux-x64-v8.0.4.30.tgz -C /usr/local/

# %%
# !cat /usr/local/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2

# %%
# %cd /content/gdrive/MyDrive/darknet/bin/darknet

# %%
# !chmod +x ./darknet

# %%
# ROI
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64 ./darknet detector test train_3.1_300frames/r1mini.data train_3.1_300frames/yolov3.cfg train_3.1_300frames/backup/yolov3_5000.weights -ext_output train_3.1_300frames/final_test/frame72.jpg

# %%
import cv2
import matplotlib.pyplot as plt


x = 238
y = 386
w = 92
h = 110
img = '/content/gdrive/MyDrive/darknet/bin/darknet/train_3.1_300frames/final_test/frame62.jpg'

# %%
result = cv2.imread(img, cv2.IMREAD_UNCHANGED)

# %%
sub_face = result[y:y+h, x:x+w]
sub_face = cv2.GaussianBlur(sub_face, (23, 23), 50)
result[y:y+sub_face.shape[0], x:x+sub_face.shape[1]] = sub_face

plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
# x, y coordinates
# 하
else: 58%    (left_x:  238   top_y:  386   width:   92   height:  110)
else: 53%    (left_x:  669   top_y:  313   width:   71   height:  111)
dom: 100%    (left_x:  863   top_y:  266   width:  153   height:  195)
else: 99%    (left_x: 1218   top_y:  262   width:  114   height:  152)

# 중
else: 95%    (left_x:  399   top_y:  324   width:   99   height:  167)
dom: 97%    (left_x:  794   top_y:  291   width:  129   height:  177)
else: 95%    (left_x: 1260   top_y:  418   width:   98   height:  128)
dom: 79%    (left_x: 1434   top_y:  313   width:   97   height:  183)
else: 44%    (left_x: 1745   top_y:  420   width:   72   height:   81)


# 상
else: 31%    (left_x:  781   top_y:  244   width:   52   height:   69)
else: 72%    (left_x: 1348   top_y:  275   width:   60   height:   79)

# %%
import cv2

else_faces = [(left_x, top_y, width, height), (left_x, top_y, width, height),]

img = 'img_path'

result = cv2.imread(img, cv2.IMREAD_UNCHANGED)

for (x, y, w, h) in else_faces:
  print(x,y,w,h,type(x))
  sub_face = result[y:y+h, x:x+w]
  sub_face = cv2.GaussianBlur(sub_face, (23, 23), 50)
  result[y:y+sub_face.shape[0], x:x+sub_face.shape[1]] = sub_face
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)

plt.imshow(result)
plt.axis('off')
# Out:
# 781 244 52 69 <class 'int'>
# 1348 275 60 79 <class 'int'>
# (-0.5, 1919.5, 1079.5, -0.5)
